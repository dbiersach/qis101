# %% [markdown]
# **Automatic differentiation with JAX.**
# There are three distinct ways to compute a derivative in software:
#
# - **Numerical differentiation** - approximate $f'(x)$ using finite differences
#   such as $(f(x+h)-f(x-h))/(2h)$. Simple but accumulates rounding error.
# - **Symbolic differentiation** - apply calculus rules to the expression tree
#   (as a computer algebra system does). Exact but can produce expensive expressions.
# - **Automatic differentiation (AD)** - decompose $f$ into primitive operations
#   (add, multiply, sin, exp, ...), apply the chain rule to each primitive,
#   and accumulate the result. Exact to machine precision, as fast as evaluating $f$.
#
# This notebook builds toward AD in three steps:
#
# 1. Estimate $f'(x)$ numerically using 4th-order centered differences and Richardson extrapolation
# 2. Verify by overlaying the hand-derived analytic derivative
# 3. Compute $f'(x)$ exactly using **JAX** automatic differentiation and inspect the primitive operation graph

# %% [markdown]
# ---
# **Step 1 - Numerical estimate of $f'(x)$.**
# The function is $f(x) = \sin(x)\,e^{-x^2}$.
# The inner function `D4` computes the 4th-order centered difference approximation
# to $f'(x)$ using five function evaluations:
#
# $$D_4(f,x,h) = \frac{-f(x+2h) + 8f(x+h) - 8f(x-h) + f(x-2h)}{12h}$$
#
# **Richardson extrapolation** then combines two estimates at step sizes $h$ and $h/2$
# to cancel the leading error term and achieve 6th-order accuracy:
#
# $$f'(x) \approx \frac{16\,D_4(h/2) - D_4(h)}{15}$$

# %%
"""jax_ad.ipynb"""

# Cell 01 - Estimate f'(x) via Richardson extrapolation on 4th-order centered differences

import matplotlib.pyplot as plt
import numpy as np


def f(x):
    return np.sin(x) * np.exp(-(x**2))


def df(x):
    """Estimate f'(x) using Richardson extrapolation on D4 centered differences."""

    def D4(f, x, h):
        """4th-order centered difference approximation to f'(x)."""
        t1, t2 = -f(x + 2 * h), 8 * f(x + h)
        t3, t4 = -8 * f(x - h), f(x - 2 * h)
        return (t1 + t2 + t3 + t4) / (12 * h)

    h = 0.01
    t1, t2 = D4(f, x, h), D4(f, x, h / 2)
    return (16 * t2 - t1) / 15  # Richardson extrapolation


a, b = 0, np.pi
x = np.linspace(a, b, 500)

plt.figure("jax_ad_numerical", figsize=(8, 4))
plt.plot(x, f(x), label=r"$f(x)=\sin(x)\cdot e^{-x^2}$")
plt.plot(x, df(x), label=r"$f'(x)$ numerical estimate")
plt.title("Numerical Derivative via Richardson Extrapolation")
plt.legend(loc="upper right")
plt.xlim(a, b)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# **Step 2 - Analytic derivative as ground truth.**
# Applying the product rule to $f(x) = \sin(x)\,e^{-x^2}$:
#
# $$f'(x) = \cos(x)\,e^{-x^2} + \sin(x)\cdot(-2x)\,e^{-x^2}
# = e^{-x^2}(\cos x - 2x\sin x)$$
#
# The analytic values (black dots, sampled every 5th point) are overlaid on the
# numerical estimate to confirm they agree.

# %%
# Cell 02 - Overlay the hand-derived analytic derivative as validation


def f_prime_analytic(x):
    return np.exp(-(x**2)) * (np.cos(x) - 2 * x * np.sin(x))


plt.figure("jax_ad_analytic", figsize=(8, 4))
plt.plot(x, f(x), label=r"$f(x)=\sin(x)\cdot e^{-x^2}$")
plt.plot(x, df(x), label=r"$f'(x)$ numerical")
plt.scatter(
    x[::5],
    f_prime_analytic(x[::5]),
    color="k",
    s=5,
    label=r"$f'(x)=e^{-x^2}(\cos x - 2x\sin x)$ analytic",
)
plt.title("Numerical vs Analytic Derivative")
plt.legend(loc="upper right")
plt.xlim(a, b)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# **Step 3 - Automatic differentiation with JAX.**
# JAX is a high-performance numerical computing library built by Google Research.
# It combines the familiar NumPy API with:
#
# - `jax.grad` - automatic differentiation (exact, to machine precision)
# - `jax.jit` - just-in-time (JIT) compilation via XLA
# - `jax.vmap` - automatic vectorization (apply a scalar function to an array)
# - `jax.pmap` - parallelization across multiple devices
#
# **JAX** stands for *Just After XLA* - XLA (Accelerated Linear Algebra) is a
# domain-specific compiler that JAX uses to compile and optimize computations
# for CPUs, GPUs, and TPUs.
#
# `jax.grad(f)` returns a new function that computes $f'$ at a single point.
# Since `x` is an array, `jax.vmap` vectorizes the call so `f_prime` is
# applied to every element simultaneously without a Python loop.
# The analytic derivative (black dots) is overlaid as in Step 2 to confirm
# that JAX AD matches the exact result.

# %%
# Cell 03 - Compute f'(x) using JAX automatic differentiation
# jax.grad: differentiates a scalar->scalar function exactly via the chain rule
# jax.vmap: vectorizes the scalar gradient so it runs over the entire x array

import jax
import jax.numpy as jnp


def f_jax(x):
    return jnp.sin(x) * jnp.exp(-(x**2))


f_prime_jax = jax.grad(f_jax)  # exact derivative function (scalar -> scalar)

f_vals = jax.vmap(f_jax)(x)  # f(x) evaluated over the array
df_vals = jax.vmap(f_prime_jax)(x)  # f'(x) evaluated over the array

plt.figure("jax_ad_autodiff", figsize=(8, 4))
plt.plot(x, f_vals, label=r"$f(x)=\sin(x)\cdot e^{-x^2}$")
plt.plot(x, df_vals, label=r"$f'(x)$ via JAX AD")
plt.scatter(
    x[::5],
    f_prime_analytic(x[::5]),
    color="k",
    s=5,
    label=r"$f'(x)=e^{-x^2}(\cos x - 2x\sin x)$ analytic",
)
plt.title("Automatic Differentiation via JAX")
plt.legend(loc="upper right")
plt.xlim(a, b)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# **Inspecting the JAXPR - the primitive operation graph.**
# A **JAXPR** (JAX Primitive Representation) is the intermediate representation
# JAX builds when it traces a function.
# It expresses the computation as a sequence of primitive operations
# (add, mul, sin, exp, ...) that JAX knows how to differentiate and compile.
#
# `jax.make_jaxpr(f_prime_jax)(1.0)` traces the derivative function at the
# scalar input `1.0` and prints the resulting operation graph,
# making the chain rule steps explicit and machine-readable.
# The annotated output below shows how JAX reconstructs $f'(x)$ from primitives.

# %%
# Cell 04 - Print the JAXPR (primitive operation graph) of f'(x)
# Each line is one primitive op; the gradient path shows the chain rule unrolled

print(jax.make_jaxpr(f_prime_jax)(1.0))

# Annotated interpretation of the output:
# { lambda ; a:f32[]. let
#     b = sin a                  # b = sin(x)
#     c = cos a                  # c = cos(x)
#     d = integer_pow[y=2] a     # d = x^2
#     e = integer_pow[y=1] a     # e = x
#     f = mul 2.0 e              # f = 2x
#     g = neg d                  # g = -x^2
#     h = exp g                  # h = e^{-x^2}
#     _ = mul b h                # f(x) = sin(x)*e^{-x^2}  (traced, not returned)
#
#     # Gradient path (chain rule unrolled):
#     i = mul b 1.0              # i = sin(x)
#     j = mul 1.0 h              # j = e^{-x^2}
#     k = mul i h                # k = sin(x)*e^{-x^2}
#     l = neg k                  # l = -sin(x)*e^{-x^2}
#     m = mul l f                # m = -2x*sin(x)*e^{-x^2}
#     n = mul j c                # n = e^{-x^2}*cos(x)
#     o = add_any m n            # o = e^{-x^2}*cos(x) - 2x*sin(x)*e^{-x^2}  <- f'(x)
#   in (o,) }

# %% [markdown]
# ---
# **All JAX primitives.**
# Every JAX computation ultimately decomposes into a fixed set of primitives
# defined in `jax.lax`.
# The function below introspects the module to collect all primitive names -
# these are the atomic operations that XLA knows how to compile and that
# JAX's AD system knows how to differentiate.

# %%
# Cell 05 - List all primitive operations available in jax.lax

import jax.extend.core
import jax.lax


def get_primitives(module):
    """Return a sorted list of JAX primitive names found in module."""
    prims = set()
    for name in dir(module):
        obj = getattr(module, name)
        if hasattr(obj, "primitive"):  # functions wrapping a primitive
            prims.add(obj.primitive.name)
        elif isinstance(obj, jax.extend.core.Primitive):  # bare primitive objects
            prims.add(obj.name)
    return sorted(prims)


lax_primitives = get_primitives(jax.lax)
print(f"Primitives found in jax.lax: {len(lax_primitives)}")
print(*lax_primitives, sep="\n")
