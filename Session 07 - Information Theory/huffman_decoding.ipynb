# %% [markdown]
# **Huffman decoding.**
# Decoding reverses the three encoding stages in order:
# 1. **Reconstruct** the Huffman tree from the serialized bytes at the
#    start of the compressed file.
# 2. **Unpack** the remaining bytes into a bitstring, stripping the
#    padding bits that were added to reach a byte boundary.
# 3. **Decode** each original byte by walking the tree one bit at a time:
#    `0` steps left, `1` steps right; whenever a leaf is reached its
#    byte value is emitted and the walk restarts from the root.
#
# A final byte-for-byte comparison against the original file confirms
# that the compression is perfectly lossless.

# %% [markdown]
# ---
# **Step 1 - Reading a Huffman-compressed binary file.**
# The `.bin` file has a two-part structure written during encoding:
# a serialized Huffman tree followed by the compressed bit-stream.
#
# The first 2 bytes store the tree length as a big-endian unsigned integer.
# `int.from_bytes(..., byteorder="big")` reconstructs that integer so the next
# read knows exactly how many bytes to consume for the tree.
# The remainder of the file is the encoded data - the compressed bit-stream
# that can only be decoded by replaying the Huffman tree.
#
# The file is opened in binary mode (`"rb"`) because the contents are raw bytes,
# not text - attempting to decode them as ASCII or UTF-8 would raise an error.

# %%
"""huffman_decoding.ipynb"""

# Cell 01 - Read the compressed binary file

from pathlib import Path

file_path = Path("AliceInWonderland.bin")

with file_path.open("rb") as infile:
    tree_len = int.from_bytes(infile.read(2), byteorder="big")
    tree_data = infile.read(tree_len)
    encoded_bytes = infile.read()

print(f"Compressed file size  : {file_path.stat().st_size:>8,} bytes")
print(f"Serialized tree size  : {tree_len + 2:>8,} bytes (incl. 2-byte length header)")
print(f"Encoded data size     : {len(encoded_bytes):>8,} bytes")

# %% [markdown]
# ---
# **Step 2 - Reconstruct the Huffman tree.**
# The tree was serialized depth-first during encoding: an internal node
# is stored as `0x00` followed by its left and right subtrees; a leaf node
# is stored as `0x01` followed by the byte value.
# Deserialization mirrors this: read the flag byte, then recurse left and
# right for internal nodes, or read the payload byte for leaves.
# A final index check confirms the entire tree buffer was consumed,
# catching any truncated or malformed data.

# %%
# Cell 02 - Reconstruct the Huffman tree from its serialized form


class Node:
    def __init__(self, byte=None, left=None, right=None):
        self.byte = byte
        self.left = left
        self.right = right


def deserialize_tree(data: bytes) -> Node:
    """Reconstruct a Huffman tree from its serialized byte sequence."""

    def helper(index: int) -> tuple[Node, int]:
        if index >= len(data):
            raise ValueError("Unexpected end of tree data")
        flag = data[index]
        index += 1
        if flag == 1:  # leaf node
            if index >= len(data):
                raise ValueError("Missing byte after leaf indicator")
            return Node(byte=data[index]), index + 1
        # internal node: recurse into left then right subtree
        left, index = helper(index)
        right, index = helper(index)
        return Node(left=left, right=right), index

    root, final_index = helper(0)
    if final_index != len(data):
        raise ValueError("Tree data not fully consumed - tree may be malformed")
    return root


tree = deserialize_tree(tree_data)

# Walk the 000 path (left-left-left) to show the tree was reconstructed correctly
path = "000"
node = tree
for bit in path:
    node = node.left if bit == "0" else node.right
print(
    f"Byte at tree path '{path}': {node.byte} (ASCII {node.byte} = {chr(node.byte)!r})"
)

# %% [markdown]
# ---
# **Step 3 - Unpack bytes into a bitstring and remove padding.**
# Each stored byte is expanded into its 8-bit binary string.
# The very first byte of the data section holds the padding count (0-7)
# that was prepended during encoding.
# Slicing `[8 : len - extra_padding]` strips both the padding-count byte
# and the trailing zero bits in one operation, recovering the exact
# bitstring that was produced during encoding.

# %%
# Cell 03 - Expand bytes to bits and strip the padding


def remove_padding(padded_data: str) -> str:
    """Strip the padding-count header byte and trailing padding zeros."""
    extra_padding = int(padded_data[:8], 2)
    end = len(padded_data) - extra_padding if extra_padding else len(padded_data)
    return padded_data[8:end]


bitstring = "".join(f"{byte:08b}" for byte in encoded_bytes)
encoded_data = remove_padding(bitstring)

print(f"Packed bitstring length  : {len(bitstring):,} bits")
print(f"After padding removal    : {len(encoded_data):,} bits")
print()
# Show the first 400 bits in 40-bit rows
for i in range(0, 400, 40):
    print(encoded_data[i : i + 40])

# %% [markdown]
# ---
# **Step 4 - Decode the bitstring by walking the tree.**
# Starting at the root, each bit steers the walk left (`0`) or right (`1`).
# Reaching a leaf emits that leaf's byte value and resets the current
# position back to the root, ready for the next codeword.
# Because the code is prefix-free, no codeword is a prefix of another,
# so this greedy left-to-right scan is always unambiguous.

# %%
# Cell 04 - Walk the tree bit by bit to recover the original bytes


def decode_data(encoded_data: str, tree: Node) -> bytearray:
    """Decode a Huffman bitstring back to the original byte sequence."""
    decoded_bytes = bytearray()
    current = tree
    for bit in encoded_data:
        current = current.left if bit == "0" else current.right
        if current.byte is not None:  # reached a leaf
            decoded_bytes.append(current.byte)
            current = tree  # reset to root for next codeword
    return decoded_bytes


decoded_bytes = decode_data(encoded_data, tree)

print(f"Decoded {len(decoded_bytes):,} bytes")
print()
text = decoded_bytes.decode("ascii")
for line in text.splitlines()[:17]:
    print(line)

# %% [markdown]
# ---
# **Step 5 - Lossless verification.**
# `filecmp.cmp` compares two files byte-for-byte when `shallow=False`,
# ignoring metadata such as timestamps.
# An identical result confirms that the full encode-then-decode round-trip
# recovers every byte of the original file without any loss.

# %%
# Cell 05 - Write the decoded file and verify it matches the original

import filecmp

original = Path("AliceInWonderland.txt")
recovered = Path("AliceInWonderland.uncompressed.txt")

recovered.write_bytes(decoded_bytes)

identical = filecmp.cmp(original, recovered, shallow=False)
print(f"Recovered file written : '{recovered.name}'")
print(f"Identical to original  : {identical}")
