# %% [markdown]
# **Huffman encoding.**
# Huffman coding is a lossless compression algorithm that assigns shorter
# bit strings to more frequent symbols and longer bit strings to rarer ones.
# Given a frequency table for all symbols in a file, it builds an optimal
# **prefix-free** binary code - no codeword is a prefix of any other,
# so the encoded bitstream can be decoded unambiguously without separators.
#
# The algorithm has three stages:
# 1. **Count** the frequency of every byte in the input file.
# 2. **Build** a binary tree by repeatedly merging the two lowest-frequency
#    nodes until a single root remains (using a min-heap for efficiency).
# 3. **Assign** codewords by traversing the tree: left edges append `0`,
#    right edges append `1`; leaf nodes receive the accumulated bit string.

# %% [markdown]
# ---
# **Step 1 - Reading a text file with `pathlib` into a list of strings.**
# `Path.read_bytes()` opens the file and returns its entire contents as a `bytes` object in one call - no context manager needed.
# The raw bytes are then decoded from ASCII into a Python string, split on newline characters into a list of lines, and the first 17 lines are printed as a preview.
#
# `bytes` and `str` are distinct types in Python: `bytes` holds raw 8-bit values, while `str` holds Unicode code points. The `.decode("ascii")` call converts between them, interpreting each byte as its ASCII character value. For a plain English text file like *Alice in Wonderland* this is safe; for files containing accented characters or non-Latin scripts you would use `"utf-8"` instead.

# %%
"""huffman_encoding.ipynb"""

# Cell 01 - Read the uncompressed text file as raw bytes

from pathlib import Path

data = Path("AliceInWonderland.txt").read_bytes()
text = data.decode("ascii")
lines = text.splitlines()

print(f"File size : {len(data):,} bytes")
print(f"Lines     : {len(lines):,}")
print()
for line in lines[:17]:
    print(line)

# %% [markdown]
# ---
# **Step 2 - Build the frequency table.**
# `Counter` counts the occurrences of each distinct byte value in the raw
# file, producing a mapping from byte value (0-255) to its frequency.
# The most frequent byte in an English text file is typically the space
# character (ASCII 32), which will therefore receive the shortest codeword.

# %%
# Cell 02 - Build the byte frequency table

from collections import Counter
from pprint import pprint

freq_table = Counter(data)

print(f"Unique byte values : {len(freq_table)}")
pprint(freq_table)

# %% [markdown]
# ---
# **Step 3 - Create a min-heap of leaf nodes.**
# Each entry in the frequency table becomes a leaf `Node` holding its
# byte value and frequency.
# `heapq.heapify` rearranges the list in-place into a **min-heap** - a
# binary heap where every node is less than or equal to its children,
# guaranteeing that `heap[0]` is always the minimum-frequency node.
# The `__lt__` method on `Node` tells the heap how to compare two nodes
# (by frequency), which `heapq` requires when the elements are not
# plain numbers.

# %%
# Cell 03 - Build a min-heap of leaf nodes from the frequency table

import heapq


class Node:
    def __init__(self, freq, byte=None, left=None, right=None):
        self.freq = freq
        self.byte = byte
        self.left = left
        self.right = right

    def __lt__(self, other):
        # Required by heapq to compare nodes when breaking frequency ties
        return self.freq < other.freq


heap = [Node(freq, byte) for byte, freq in freq_table.items()]
heapq.heapify(heap)

# After heapify, heap[0] is the rarest byte and heap[-1] is among the most common
print(f"Rarest byte : {heap[0].byte} (freq = {heap[0].freq:,})")
print(f"Common byte : {heap[-1].byte} (freq = {heap[-1].freq:,})")

# %% [markdown]
# ---
# **Step 4 - Build the Huffman tree.**
# Repeatedly pop the two lowest-frequency nodes from the heap, merge them
# into a new internal node whose frequency is their sum, and push the
# merged node back.
# Each merge reduces the heap size by one; after $n-1$ merges a single
# root node remains, and its frequency equals the total number of bytes
# in the file - a useful sanity check.

# %%
# Cell 04 - Merge nodes until a single root remains

while len(heap) > 1:
    node1 = heapq.heappop(heap)  # lowest frequency
    node2 = heapq.heappop(heap)  # second lowest frequency
    merged = Node(node1.freq + node2.freq, left=node1, right=node2)
    heapq.heappush(heap, merged)

tree = heap[0]

print(f"Root frequency : {tree.freq:,}")
print(f"File size      : {len(data):,}")

# %% [markdown]
# ---
# **Step 5 - Assign codewords by traversing the tree.**
# A depth-first traversal of the tree assigns each leaf node its codeword:
# taking a left branch appends `0` and taking a right branch appends `1`.
# Frequent bytes end up near the root (short codewords) and rare bytes
# near the leaves (long codewords).
#
# Note that `code_table` uses `None` as its default argument rather than
# `{}` - using a mutable object as a default argument is a common Python
# pitfall because the default is created once at function definition time
# and shared across all calls, causing stale entries to accumulate.

# %%
# Cell 05 - Traverse the tree recursively to build the codeword table


def build_code_table(
    node: Node,
    prefix: str = "",
    code_table: dict[int, str] | None = None,
) -> dict[int, str]:
    if code_table is None:
        code_table = {}  # create a fresh dict on each top-level call
    if node is None:
        return code_table
    if node.byte is not None:
        code_table[node.byte] = prefix
    build_code_table(node.left, prefix + "0", code_table)
    build_code_table(node.right, prefix + "1", code_table)
    return code_table


code_table = build_code_table(tree)

print(
    f"Codeword for 'e' (ASCII 101) : {code_table.get(101)}  ({len(code_table.get(101))} bits)"
)
print(
    f"Codeword for 'Z' (ASCII  90) : {code_table.get(90)}  ({len(code_table.get(90))} bits)"
)
print()
# Display codewords sorted by length (longest first) to show rare-byte penalty
pprint(sorted(code_table.items(), key=lambda x: len(x[1]), reverse=True))

# %% [markdown]
# ---
# **Step 6 - Encoding the file.**
# Each byte in the input is replaced by its codeword from the table,
# producing a long binary string.
# The encoded string will be significantly shorter than the original
# because common bytes have short codewords - for example, the space
# character (which appears ~17% of the time) may be encoded in just
# 3-4 bits instead of the standard 8.

# %%
# Cell 06 - Replace every byte with its Huffman codeword

encoded_data = "".join(code_table[byte] for byte in data)

print(f"Original size  : {len(data) * 8:,} bits = {len(data):,} bytes")
print(f"Encoded size   : {len(encoded_data):,} bits")
print()
# Show the first 400 bits in 40-bit rows
for i in range(0, 400, 40):
    print(encoded_data[i : i + 40])

# %% [markdown]
# ---
# **Step 7 - Writing the compressed file.**
# The encoded bitstream must be packed into bytes before writing to disk.
# Since the total number of bits may not be a multiple of 8, padding zeros
# are appended to reach the next byte boundary.
# The number of padding bits (0-7) is stored in the first byte of the file
# so the decoder can strip them on reading.
# The Huffman tree itself is serialized ahead of the data so the decoder
# can reconstruct it: leaf nodes are written as `0x01` followed by the
# byte value; internal nodes are written as `0x00` followed by their
# left and right subtrees recursively.

# %%
# Cell 07 - Pack bits into bytes and write the compressed file


def pad_encoded_data(encoded_data: str) -> str:
    """Pad the bitstream to a multiple of 8 and prepend the padding count."""
    # (8 - n%8) % 8 gives 0 when already aligned, not 8
    extra_padding = (8 - len(encoded_data) % 8) % 8
    encoded_data += "0" * extra_padding
    return f"{extra_padding:08b}" + encoded_data


def get_byte_array(padded_encoded_data: str) -> bytearray:
    """Convert a padded bitstring into a bytearray, 8 bits at a time."""
    b = bytearray()
    for i in range(0, len(padded_encoded_data), 8):
        b.append(int(padded_encoded_data[i : i + 8], 2))
    return b


def serialize_tree(node: Node) -> bytes:
    """Serialize the Huffman tree as a byte sequence for storage."""
    if node.byte is not None:
        return b"\x01" + bytes([node.byte])  # leaf: marker + byte value
    return b"\x00" + serialize_tree(node.left) + serialize_tree(node.right)


tree_data = serialize_tree(tree)
padded_data = pad_encoded_data(encoded_data)
byte_array = get_byte_array(padded_data)

with open("AliceInWonderland.bin", "wb") as outfile:
    # Write 2-byte big-endian tree size, then the serialized tree, then the data
    outfile.write(len(tree_data).to_bytes(2, byteorder="big"))
    outfile.write(tree_data)
    outfile.write(bytes(byte_array))

print(f"Created file '{outfile.name}'")
print(f"Uncompressed : {len(data):>8,} bytes")
print(f"Compressed   : {len(byte_array):>8,} bytes")
print(f"Reduction    :   {1 - len(byte_array) / len(data):.2%}")
