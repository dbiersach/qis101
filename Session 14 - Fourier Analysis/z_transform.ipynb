# %% [markdown]
# **Z-Transform Signal Decomposition.**
# This notebook demonstrates how to decompose a damped sinusoidal signal into its
# constituent modes using the Z-transform. The pipeline has five stages:
#
# 1. **Generate** a synthetic damped signal $y(t)$
# 2. **Estimate** the model order via SVD of a Hankel matrix
# 3. **Extract** discrete Z-poles and residues via linear prediction
# 4. **Interpret** the poles as physical decay rates, frequencies, amplitudes, and phases
# 5. **Reconstruct** the signal from the extracted modes and validate against the original

# %% [markdown]
# **Generate and plot the signal.**
# The signal is defined as:
#
# $$y(t) = 13\,e^{-t}\bigl(17\cos(3t) + 7\sin(23t)\bigr)$$
#
# This is a sum of two damped sinusoids sharing a common exponential envelope $e^{-t}$.
# Expanding using the identity $A\cos(\omega t + \phi) = \text{Re}\{A\,e^{j(\omega t+\phi)}\}$,
# the signal consists of two complex-conjugate mode pairs - one at $\omega = 3$ rad/s and one
# at $\omega = 23$ rad/s - giving a true model order of **4**.
#
# The time axis is sampled uniformly over $[0,\, 2\pi)$ with `endpoint=False` to avoid
# duplicating the endpoint, which would alias the last sample.

# %%
"""z_transform.ipynb"""

# Cell 01 - Generate and plot the signal

import matplotlib.pyplot as plt
import numpy as np

N_points = 1000
t = np.linspace(0, 2 * np.pi, N_points, endpoint=False)
dt = t[1] - t[0]  # time increment
y = 13 * np.exp(-t) * (17 * np.cos(3 * t) + 7 * np.sin(23 * t))

plt.figure("z_transform_signal", figsize=(8, 4))
plt.plot(t, y)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Sampled Data")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Estimate the model order via Hankel SVD.**
# Before extracting poles, we need to know how many modes are present in the signal.
# The approach here is to arrange the signal samples into a **Hankel matrix** $H$, where
# element $H[i,j] = y[i+j]$, and then examine its singular values.
#
# For a noise-free signal composed of $p$ exponential modes, $H$ has rank exactly $p$:
# only $p$ singular values are non-zero. In practice we threshold relative to the largest
# singular value:
#
# $$\text{order} = \#\left\{\sigma_k : \sigma_k > \sigma_{\max} \cdot \tau\right\}$$
#
# where $\tau$ is `tol_factor`. For clean synthetic signals $\tau = 10^{-6}$ works well.
# For real-world noisy data, $\tau$ typically needs to be much larger ($10^{-2}$ to $10^{-1}$)
# and requires careful tuning - the estimated order directly determines whether the
# Z-pole extraction succeeds or diverges.
#
# The Hankel matrix is built with $L = \lfloor N/2 \rfloor$ rows and $M = N - L + 1$ columns,
# a common choice that balances row and column dimensions for the SVD.

# %%
# Cell 02 - Estimate the model order using SVD on a Hankel matrix


def estimate_model_order(y, L_ratio=0.5, tol_factor=1e-6):
    """
    Estimate the effective model order by constructing a Hankel matrix from y
    and computing its singular values.

    Parameters
    ----------
    y          : array_like
        The signal samples.
    L_ratio    : float
        Fraction of N to use for the Hankel matrix row dimension.
        For example, L_ratio=0.5 means L = N//2.
    tol_factor : float
        Tolerance factor relative to the max singular value used to decide
        which singular values are significant. For clean synthetic signals
        1e-6 works well; real-world noisy signals typically require a much
        larger value (e.g. 1e-2 to 1e-1) and careful tuning, since the
        estimated order directly affects whether the Z-pole extraction
        succeeds or diverges.

    Returns
    -------
    order_est : int
        Estimated model order (number of significant modes).
    s         : ndarray
        Singular values of the Hankel matrix.
    """
    N = len(y)
    # Choose L (number of rows) as a fraction of the length. A common choice is L ~ N/2
    L = int(N * L_ratio)
    M = N - L + 1  # number of columns
    # Build the Hankel matrix H, where H[i,j] = y[i+j]
    H = np.empty((L, M))
    for i in range(L):
        H[i, :] = y[i : i + M]
    # Perform SVD on H
    _, s, _ = np.linalg.svd(H, full_matrices=False)
    # Determine the number of singular values above a threshold
    tol = np.max(s) * tol_factor
    order_est = int(np.sum(s > tol))
    return order_est, s


# Estimate the model order from the data
estimated_order, singular_values = estimate_model_order(y, L_ratio=0.5, tol_factor=1e-6)
print("Estimated model order:", estimated_order)

# %% [markdown]
# **Extract Z-poles and residues via linear prediction.**
# With the model order known, we extract the discrete Z-poles using **linear prediction**.
# The key assumption is that each sample can be expressed as a linear combination of the
# preceding `order` samples:
#
# $$y[n + \text{order}] = -\sum_{k=1}^{\text{order}} a_k\, y[n + \text{order} - k]$$
#
# Stacking these equations for all valid $n$ gives an overdetermined linear system
# $Y \mathbf{a} = -\mathbf{b}$, solved in the least-squares sense.
#
# The prediction coefficients $\{a_k\}$ define a polynomial whose **roots are the discrete
# Z-poles** $z_k$. Each pole is then converted to a continuous exponent:
#
# $$\lambda_k = \frac{\ln z_k}{\Delta t}$$
#
# where $\text{Re}(\lambda_k)$ is the decay rate and $\text{Im}(\lambda_k)$ is the
# angular frequency $\omega_k$.
#
# Finally, the **residues** $c_k$ (complex amplitudes) are recovered by solving a second
# least-squares system built from a Vandermonde matrix $V$, where
# $V[n,k] = z_k^n$, so that $V\,\mathbf{c} \approx \mathbf{y}$.

# %%
# Cell 03 - Extract Z-poles and residues via linear prediction


def z_transform_extraction(y, t, order):
    """
    Extract poles (continuous exponents) and residues using a Z-transform method.

    Parameters
    ----------
    y     : array_like
        The signal samples.
    t     : array_like
        Time samples.
    order : int
        Model order (number of exponential terms).

    Returns
    -------
    lam     : ndarray
        Continuous exponents (lambda_k = ln(z_k) / dt).
    c       : ndarray
        Residues for each mode.
    z_poles : ndarray
        Discrete Z-poles.
    """
    N = len(y)
    dt = t[1] - t[0]
    L_pred = N - order

    # Build the linear prediction matrix: each row n is
    # [y[n+order-1], y[n+order-2], ..., y[n]]
    Y_matrix = np.empty((L_pred, order))
    for n in range(L_pred):
        Y_matrix[n, :] = y[n : n + order][::-1]
    b_vector = -y[order:N]

    # Solve for the prediction coefficients using least squares
    a_est, _, _, _ = np.linalg.lstsq(Y_matrix, b_vector, rcond=None)
    # Full polynomial: 1 + a1*z^{-1} + ... + a_order*z^{-order} = 0
    coeffs = np.concatenate(([1.0], a_est))

    # Find the roots (the discrete Z-poles)
    z_poles = np.roots(coeffs)
    # Convert to continuous exponents: lambda = ln(z) / dt
    lam = np.log(z_poles) / dt

    # Solve for the residues c_k using a Vandermonde matrix.
    # V has shape (N, order): row n is [z_0^n, z_1^n, ..., z_{order-1}^n],
    # so each column corresponds to one mode and V @ c = y.
    V = np.vander(z_poles, N, increasing=True).T
    c, _, _, _ = np.linalg.lstsq(V, y, rcond=None)

    return lam, c, z_poles


# Use the estimated order
order = estimated_order
lam, c, z_poles = z_transform_extraction(y, t, order)

print("\nExtracted Z-poles (z):")
print(z_poles)
print("\nContinuous exponents (lambda):")
print(lam)
print("\nResidues (c):")
print(c)

# %% [markdown]
# **Interpret poles as physical components.**
# The extracted poles come in complex-conjugate pairs. For a conjugate pair
# $(\lambda_k,\, \bar{\lambda}_k)$ with residues $(c_k,\, \bar{c}_k)$, the combined
# contribution to the real-valued signal is:
#
# $$2\,|c_k|\,e^{\,\text{Re}(\lambda_k)\,t}\cos\!\bigl(\text{Im}(\lambda_k)\,t + \angle c_k\bigr)$$
#
# This lets us read off four physically meaningful quantities from each pair:
#
# | Quantity | Expression |
# |---|---|
# | Decay rate | $\text{Re}(\lambda_k)$ - expected $\approx -1$ from $e^{-t}$ |
# | Frequency | $|\text{Im}(\lambda_k)|$ in rad/s |
# | Amplitude | $2\,|c_k|$ |
# | Phase | $\angle\, c_k$ in radians |
#
# Conjugate matching uses a nearest-neighbour search rather than a fixed threshold,
# making it more robust when poles are closely spaced. Any unpaired real poles are
# reported separately rather than silently discarded.

# %%
# Cell 04 - Group conjugate pairs and extract physical quantities

components = []
unpaired = []
tol = 1e-2  # tolerance for matching conjugate pairs

used_indices = set()
for i in range(len(lam)):
    if i in used_indices:
        continue
    # Find the index of the closest conjugate match among remaining poles
    best_j = None
    best_err = np.inf
    for j in range(i + 1, len(lam)):
        if j in used_indices:
            continue
        err = abs(lam[j] - np.conjugate(lam[i]))
        if err < tol and err < best_err:
            best_err = err
            best_j = j
    if best_j is not None:
        used_indices.add(i)
        used_indices.add(best_j)
        lam_i = lam[i]
        c_i = c[i]
        decay = np.real(lam_i)  # Expected to be around -1 from the e^(-t) factor
        frequency = np.abs(np.imag(lam_i))
        # For a conjugate pair the contribution is:
        # 2 |c_i| exp(decay * t) cos(frequency*t + phase)
        amplitude = 2 * np.abs(c_i)
        phase = np.angle(c_i)
        components.append(
            {
                "decay": decay,
                "frequency": frequency,
                "amplitude": amplitude,
                "phase": phase,
            }
        )
    else:
        # Real pole (no conjugate partner found) - record but do not discard
        used_indices.add(i)
        unpaired.append({"index": i, "lambda": lam[i], "residue": c[i]})

print("\nExtracted Components:")
for comp in components:
    print("Component:")
    print("  Decay exponent: {:.3f}".format(comp["decay"]))
    print("  Frequency:      {:.3f} rad/s".format(comp["frequency"]))
    print("  Amplitude:      {:.3f}".format(comp["amplitude"]))
    print("  Phase:          {:.3f} rad".format(comp["phase"]))

if unpaired:
    print(f"\nNote: {len(unpaired)} unpaired (real) pole(s) found:")
    for p in unpaired:
        print("  index={index}  lambda={lambda:.4f}  residue={residue:.4f}".format(**p))

# %% [markdown]
# **Reconstruct and validate the signal.**
# These three lines evaluate the Z-domain signal reconstruction formula at every time step.
#
# The core idea is that the Z-transform extraction decomposed the signal into
# `order` modes, each characterized by a Z-pole $z_k$ and a residue $c[k]$. The reconstructed
# signal at time step $n$ is:
#
# $$y[n] = \sum_k c[k] \cdot z_k^n$$
#
# `np.vander(z_poles, n_pts, increasing=True)` builds an
# $(\text{order} \times n\_pts)$ matrix where row $k$ is
# $\bigl[z_k^0,\ z_k^1,\ \ldots,\ z_k^{n\_pts-1}\bigr]$ - all the powers of one pole
# across every time step. The `.T` transposes it to $(n\_pts \times \text{order})$ so that
# row $n$ contains $\bigl[z_0^n,\ z_1^n,\ \ldots,\ z_{\text{order}-1}^n\bigr]$ - all poles
# evaluated at one time step:
#
# $$V_{\text{recon}}[n,\, k] = z_k^n$$
#
# Then `.dot(c)` multiplies each row by the residues and sums across all modes:
#
# $$y_{\text{recon}}[n] = \sum_k c[k] \cdot z_k^n$$
#
# Close agreement between the original and reconstructed signals confirms that the
# extracted poles and residues faithfully represent the signal.

# %%
# Cell 05 - Reconstruct and plot the signal for validation

n_pts = len(t)  # use len(t) rather than N_points for cell independence
# V_recon[n, k] = z_poles[k]^n, giving an (n_pts x order) matrix where y ≈ V_recon @ c
V_recon = np.vander(z_poles, n_pts, increasing=True).T
# Sum all mode contributions: y_recon[n] = sum_k c[k] * z_poles[k]^n
y_recon = V_recon.dot(c)

plt.figure("z_transform_reconstruction", figsize=(8, 4))
plt.plot(t, y, label="Original Signal")
plt.plot(t, np.real(y_recon), "--", label="Reconstructed Signal")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend()
plt.title("Signal Reconstruction via Z-Transform")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
